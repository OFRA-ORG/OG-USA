# %%
import os, glob
import pandas as pd

# %%
pd.options.display.float_format = "{:,.3f}".format

# %%
df_cbo = pd.read_csv('cbo.csv')
df_cbo['Revenues (trillions)'] = df_cbo['Revenues (pct of GDP)'] * df_cbo['Nominal GDP (trillions)'] / 100
df_cbo['Spending (trillions)'] = df_cbo['Spending (pct of GDP)'] * df_cbo['Nominal GDP (trillions)'] / 100

# %%
def add_rev_entry(idx, folder_name, df_cbo, results_dict):
    file_name = folder_name + '/plots_and_tables/macro_time_series_output.csv'
    df = pd.read_csv(file_name)
    df = df[df['Year']<=2035]
    pct_diff_rev = (df['Total tax revenue ($REV_t$): Reform'] - df['Total tax revenue ($REV_t$): Baseline'])/df['Total tax revenue ($REV_t$): Baseline']

    df_cbo_i = df_cbo.copy()
    dollar_diff_rev = pct_diff_rev * df_cbo_i['Revenues (trillions)']

    results_dict[idx] = [folder_name, 'diff_rev'] + dollar_diff_rev.to_list()

# %%
def add_spend_entry(idx, folder_name, df_cbo, results_dict):
    file_name = folder_name + '/plots_and_tables/macro_time_series_output.csv'
    df = pd.read_csv(file_name)
    df = df[df['Year']<=2035]
    pct_diff_spend = (df['Government Expenditures ($G_t$): Reform'] - df['Government Expenditures ($G_t$): Baseline'])/df['Government Expenditures ($G_t$): Baseline']

    df_cbo_i = df_cbo.copy()
    dollar_diff_spend = pct_diff_spend * df_cbo_i['Spending (trillions)']

    results_dict[idx] = [folder_name, 'diff_spend'] + dollar_diff_spend.to_list()

# %%
# Initializing an empty dictionary 
results_dict = {}

# %% [markdown]
# ### Based sim

# %%
model = 'TCJA_TMD'
frisch = '0.4'
zeta_D = '0.4'
g_y_annual = '0.02'
tG1 = '20'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1

# %%
add_rev_entry(0, folder_name, df_cbo, results_dict)
add_spend_entry(1, folder_name, df_cbo, results_dict)

# %% [markdown]
# ### Stronger labor supply response

# %%
model = 'TCJA_TMD'
frisch = '0.6'
zeta_D = '0.4'
g_y_annual = '0.02'
tG1 = '20'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1

# %%
add_rev_entry(2, folder_name, df_cbo, results_dict)
add_spend_entry(3, folder_name, df_cbo, results_dict)

# %% [markdown]
# ### More open economy

# %%
model = 'TCJA_TMD'
frisch = '0.4'
zeta_D = '0.6'
g_y_annual = '0.02'
tG1 = '20'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1

# %%
add_rev_entry(4, folder_name, df_cbo, results_dict)
add_spend_entry(5, folder_name, df_cbo, results_dict)

# %% [markdown]
# ### More leniency on budget closure

# %%
model = 'TCJA_TMD'
frisch = '0.4'
zeta_D = '0.4'
g_y_annual = '0.02'
tG1 = '40'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1

# %%
add_rev_entry(6, folder_name, df_cbo, results_dict)
add_spend_entry(7, folder_name, df_cbo, results_dict)

# %% [markdown]
# ### Immigration impact

# %%
model = 'TCJA_TMD_immig'
frisch = '0.4'
zeta_D = '0.4'
g_y_annual = '0.02'
tG1 = '20'
immig_mil = '1'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1+"##immig_mil##"+immig_mil

# %%
add_rev_entry(8, folder_name, df_cbo, results_dict)
add_spend_entry(9, folder_name, df_cbo, results_dict)

# %%
model = 'TCJA_TMD_immig'
frisch = '0.4'
zeta_D = '0.4'
g_y_annual = '0.02'
tG1 = '20'
immig_mil = '2'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1+"##immig_mil##"+immig_mil

# %%
add_rev_entry(10, folder_name, df_cbo, results_dict)
add_spend_entry(11, folder_name, df_cbo, results_dict)

# %% [markdown]
# ### Spending cut impact

# %%
model = 'TCJA_TMD_spend'
frisch = '0.4'
zeta_D = '0.4'
g_y_annual = '0.02'
tG1 = '20'
spendng_cut = '0.05'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1+"##spend##"+spendng_cut

# %%
add_rev_entry(12, folder_name, df_cbo, results_dict)
add_spend_entry(13, folder_name, df_cbo, results_dict)

# %%
model = 'TCJA_TMD_spend'
frisch = '0.4'
zeta_D = '0.4'
g_y_annual = '0.02'
tG1 = '20'
spendng_cut = '0.1'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##g_y_annual##"+g_y_annual+"##tG1##"+tG1+"##spend##"+spendng_cut

# %%
add_rev_entry(14, folder_name, df_cbo, results_dict)
add_spend_entry(15, folder_name, df_cbo, results_dict)

# %% [markdown]
# ### Productivity growth

# %%
model = 'TCJA_TMD_prod'
frisch = '0.4'
zeta_D = '0.4'
Z = '1.02'
tG1 = '20'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##Z##"+Z+"##tG1##"+tG1

# %%
add_rev_entry(16, folder_name, df_cbo, results_dict)
add_spend_entry(17, folder_name, df_cbo, results_dict)

# %%
model = 'TCJA_TMD_prod'
frisch = '0.4'
zeta_D = '0.4'
Z = '1.04'
tG1 = '20'
folder_name = model+"##frisch##"+frisch+"##zeta_D##"+zeta_D+"##Z##"+Z+"##tG1##"+tG1

# %%
add_rev_entry(18, folder_name, df_cbo, results_dict)
add_spend_entry(19, folder_name, df_cbo, results_dict)

# %% [markdown]
# ### Aggregation

# %%
df_results = pd.DataFrame.from_dict(
    results_dict, orient='index',
    columns=[
        'model', 'var', '2026', '2027', '2028', '2029', '2030', '2031', '2032', '2033', '2034', '2035'
    ]
)

# %%
df_results
# Out:
#                                                 model         var   2026  \
# 0   TCJA_TMD##frisch##0.4##zeta_D##0.4##g_y_annual...    diff_rev -0.310
# 1   TCJA_TMD##frisch##0.4##zeta_D##0.4##g_y_annual...  diff_spend  0.069
# 2   TCJA_TMD##frisch##0.6##zeta_D##0.4##g_y_annual...    diff_rev -0.290
# 3   TCJA_TMD##frisch##0.6##zeta_D##0.4##g_y_annual...  diff_spend  0.093
# 4   TCJA_TMD##frisch##0.4##zeta_D##0.6##g_y_annual...    diff_rev -0.318
# 5   TCJA_TMD##frisch##0.4##zeta_D##0.6##g_y_annual...  diff_spend  0.059
# 6   TCJA_TMD##frisch##0.4##zeta_D##0.4##g_y_annual...    diff_rev -0.310
# 7   TCJA_TMD##frisch##0.4##zeta_D##0.4##g_y_annual...  diff_spend  0.069
# 8   TCJA_TMD_immig##frisch##0.4##zeta_D##0.4##g_y_...    diff_rev -0.290
# 9   TCJA_TMD_immig##frisch##0.4##zeta_D##0.4##g_y_...  diff_spend  0.093
# 10  TCJA_TMD_immig##frisch##0.4##zeta_D##0.4##g_y_...    diff_rev -0.270
# 11  TCJA_TMD_immig##frisch##0.4##zeta_D##0.4##g_y_...  diff_spend  0.117
# 12  TCJA_TMD_spend##frisch##0.4##zeta_D##0.4##g_y_...    diff_rev -0.310
# 13  TCJA_TMD_spend##frisch##0.4##zeta_D##0.4##g_y_...  diff_spend -0.291
# 14  TCJA_TMD_spend##frisch##0.4##zeta_D##0.4##g_y_...    diff_rev -0.311
# 15  TCJA_TMD_spend##frisch##0.4##zeta_D##0.4##g_y_...  diff_spend -0.651
# 16  TCJA_TMD_prod##frisch##0.4##zeta_D##0.4##Z##1....    diff_rev -0.242
# 17  TCJA_TMD_prod##frisch##0.4##zeta_D##0.4##Z##1....  diff_spend  0.151
# 18  TCJA_TMD_prod##frisch##0.4##zeta_D##0.4##Z##1....    diff_rev -0.186
# 19  TCJA_TMD_prod##frisch##0.4##zeta_D##0.4##Z##1....  diff_spend  0.220
#
#      2027   2028   2029   2030   2031   2032   2033   2034   2035
# 0  -0.330 -0.341 -0.357 -0.374 -0.388 -0.403 -0.421 -0.440 -0.459
# 1   0.071  0.075  0.077  0.079  0.080  0.081  0.081  0.080  0.079
# 2  -0.311 -0.322 -0.338 -0.355 -0.370 -0.385 -0.402 -0.421 -0.440
# 3   0.095  0.099  0.102  0.104  0.105  0.107  0.107  0.108  0.107
# 4  -0.340 -0.335 -0.350 -0.367 -0.382 -0.397 -0.414 -0.434 -0.454
# 5   0.060  0.093  0.099  0.102  0.105  0.108  0.110  0.112  0.112
# 6  -0.330 -0.340 -0.357 -0.373 -0.388 -0.402 -0.420 -0.439 -0.458
# 7   0.072  0.075  0.078  0.079  0.081  0.082  0.082  0.082  0.081
# 8  -0.308 -0.318 -0.334 -0.349 -0.362 -0.376 -0.392 -0.410 -0.428
# 9   0.098  0.103  0.108  0.112  0.115  0.119  0.121  0.123  0.124
# 10 -0.287 -0.296 -0.310 -0.324 -0.337 -0.349 -0.364 -0.380 -0.397
# 11  0.124  0.132  0.139  0.145  0.150  0.156  0.161  0.166  0.170
# 12 -0.330 -0.341 -0.358 -0.374 -0.388 -0.402 -0.420 -0.438 -0.457
# 13 -0.657 -1.031 -1.433 -1.495 -1.564 -1.640 -1.722 -1.807 -1.889
# 14 -0.331 -0.342 -0.358 -0.374 -0.388 -0.402 -0.419 -0.437 -0.455
# 15 -1.348 -2.025 -2.722 -2.839 -2.968 -3.111 -3.263 -3.420 -3.572
# 16 -0.105  0.042  0.222  0.430  0.669  0.942  1.268  1.660  2.131
# 17  0.337  0.526  0.777  1.066  1.408  1.814  2.299  2.880  3.579
# 18  0.106  0.443  0.842  1.310  1.857  2.503  3.300  4.293  5.525
# 19  0.586  1.017  1.549  2.176  2.936  3.869  5.021  6.452  8.233

# %%
df_results.to_csv('results.csv')

# %% [markdown]
# ### Archive

# %%
# for idx, folder_name in enumerate(glob.glob('*##*')):
#     try:
#         file_name = folder_name + '/plots_and_tables/macro_time_series_output.csv'
#         df = pd.read_csv(file_name)
#         df = df[df['Year']<=2035]
        
#         pct_diff_rev = (df['Total tax revenue ($REV_t$): Reform'] - df['Total tax revenue ($REV_t$): Baseline'])/df['Total tax revenue ($REV_t$): Baseline']
#         pct_diff_spd = (df['Government Expenditures ($G_t$): Reform'] - df['Government Expenditures ($G_t$): Baseline'])/df['Government Expenditures ($G_t$): Baseline']
#         df_cbo_i = df_cbo.copy()
#         df_cbo_i['Revenues_reform (trillions)'] = pct_diff_rev * df_cbo_i['Revenues (trillions)'] + df_cbo_i['Revenues (trillions)']
#         df_cbo_i['Spending_reform (trillions)'] = pct_diff_spd * df_cbo_i['Spending (trillions)'] + df_cbo_i['Spending (trillions)']
#         rev_diff_tn = df_cbo_i['Revenues_reform (trillions)'].sum() - df_cbo_i['Revenues (trillions)'].sum()
#         spd_diff_tn = df_cbo_i['Spending_reform (trillions)'].sum() - df_cbo_i['Spending (trillions)'].sum()
#         deficit_diff_tn = rev_diff_tn - spd_diff_tn
#         value_data_source = folder_name.split('##')[0]
#         value_frisch = folder_name.split('##')[2]
#         value_zeta_D = folder_name.split('##')[4]
#         value_g_y_annual = folder_name.split('##')[6]
#         value_tG1 = folder_name.split('##')[8]
#         if value_tG1=='None':
#             value_tG1 = '20'
    
#         results_dict[idx] = [value_data_source, value_frisch, value_zeta_D, value_g_y_annual, value_tG1, rev_diff_tn, spd_diff_tn, deficit_diff_tn]

#     except:
#         print("Failed and skipped " + folder_name)

# %%
# df_results = pd.DataFrame.from_dict(
#     results_dict, orient='index',
#     columns=[
#         'data source', 'frisch', 'zeta_D', 'g_y_annual', 'tG1',
#         'rev_diff_tn', 'spd_diff_tn', 'deficit_diff_tn'
#     ]
# ).sort_values(by=['data source', 'frisch', 'zeta_D', 'g_y_annual', 'tG1']).round(3)

# %%
# df_results

# %%
# df_results.to_csv('results.csv')
