# %%
from run_og_usa_ext_tmd import *
from itertools import product

# %%
# for frisch, zeta_D, g_y_annual, tG1 in product([0.3, 0.4], [0.2, 0.4], [0.02, 0.03], [5, 15, 20, 40]):
#     main(frisch, zeta_D, g_y_annual, tG1)
#     print(frisch), print(zeta_D), print(g_y_annual), print(tG1)
# Out:
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.02##tG1##5
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.02##tG1##15
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.02##tG1##20
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.02##tG1##40
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.03##tG1##5
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.03##tG1##15
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.03##tG1##20
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.2##g_y_annual##0.03##tG1##40
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.4##g_y_annual##0.02##tG1##5
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.4##g_y_annual##0.02##tG1##15
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.4##g_y_annual##0.02##tG1##20
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.4##g_y_annual##0.02##tG1##40
# Already did: TCJA_TMD##frisch##0.3##zeta_D##0.4##g_y_annual##0.03##tG1##5
# ...

# %%
frisch = 0.6
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 20
main(frisch, zeta_D, g_y_annual, tG1)
# Out:
# Number of workers =  5
# Using baseline tax parameters from  /Users/weifeng/GitHub/OG-USA/examples/TCJA_TMD##frisch##0.6##zeta_D##0.4##g_y_annual##0.02##tG1##20/OUTPUT_BASELINE/TxFuncEst_baseline.pkl
# BW =  12 begin year =  2023 end year =  2034
# /Users/weifeng/opt/anaconda3/envs/og_usa/lib/python3.11/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 216.55 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Finished tax function loop through 12 years and 1 ages per year.
# Tax function estimation time: 1 min, 17.2 sec
# /Users/weifeng/GitHub/OG-USA/ogusa/macro_params.py:110: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ...

# %%
frisch = 0.4
zeta_D = 0.6
g_y_annual = 0.02
tG1 = 20
main(frisch, zeta_D, g_y_annual, tG1)
# Out:
# Number of workers =  5
# Using baseline tax parameters from  /Users/weifeng/GitHub/OG-USA/examples/TCJA_TMD##frisch##0.4##zeta_D##0.6##g_y_annual##0.02##tG1##20/OUTPUT_BASELINE/TxFuncEst_baseline.pkl
# BW =  12 begin year =  2023 end year =  2034
# /Users/weifeng/opt/anaconda3/envs/og_usa/lib/python3.11/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 216.55 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Finished tax function loop through 12 years and 1 ages per year.
# Tax function estimation time: 1 min, 35.2 sec
# /Users/weifeng/GitHub/OG-USA/ogusa/macro_params.py:110: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ...

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 40
main(frisch, zeta_D, g_y_annual, tG1)
# Out:
# Already did: TCJA_TMD##frisch##0.4##zeta_D##0.4##g_y_annual##0.02##tG1##40

# %%
from run_og_usa_ext_tmd_immig import *

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 20
immig_mil = 1
main_immig(frisch, zeta_D, g_y_annual, tG1, immig_mil)
# Out:
# Number of workers =  5
# Using baseline tax parameters from  /Users/weifeng/GitHub/OG-USA/examples/TCJA_TMD_immig##frisch##0.4##zeta_D##0.4##g_y_annual##0.02##tG1##20##immig_mil##1/OUTPUT_BASELINE/TxFuncEst_baseline.pkl
# BW =  12 begin year =  2023 end year =  2034
# /Users/weifeng/opt/anaconda3/envs/og_usa/lib/python3.11/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 216.55 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Finished tax function loop through 12 years and 1 ages per year.
# Tax function estimation time: 1 min, 17.2 sec
# /Users/weifeng/GitHub/OG-USA/ogusa/macro_params.py:110: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ...

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 20
immig_mil = 2
main_immig(frisch, zeta_D, g_y_annual, tG1, immig_mil)

# %%
from run_og_usa_ext_tmd_spend import *

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 20
spending_cut = 0.05
main_spend(frisch, zeta_D, g_y_annual, tG1, spending_cut)
# Out:
# Number of workers =  5
# Using baseline tax parameters from  /Users/weifeng/GitHub/OG-USA/examples/TCJA_TMD_spend##frisch##0.4##zeta_D##0.4##g_y_annual##0.02##tG1##20##spend##0.05/OUTPUT_BASELINE/TxFuncEst_baseline.pkl
# BW =  12 begin year =  2023 end year =  2034
# /Users/weifeng/opt/anaconda3/envs/og_usa/lib/python3.11/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 216.55 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Finished tax function loop through 12 years and 1 ages per year.
# Tax function estimation time: 1 min, 16.8 sec
# /Users/weifeng/GitHub/OG-USA/ogusa/macro_params.py:110: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ...

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 20
spending_cut = 0.1
main_spend(frisch, zeta_D, g_y_annual, tG1, spending_cut)

# %%
from run_og_usa_ext_tmd_prod import *

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual_baseline = 0.02
g_y_annual_reform = 0.03
tG1 = 20
main_prod(frisch, zeta_D, g_y_annual_baseline, g_y_annual_reform, tG1)

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual_baseline = 0.02
g_y_annual_reform = 0.04
tG1 = 20
main_prod(frisch, zeta_D, g_y_annual_baseline, g_y_annual_reform, tG1)
