# %%
import ogusa.growfactor_update as gf

# %%
model_folder = 'TCJA_TMD##frisch##0.4##zeta_D##0.4##g_y_annual##0.02##tG1##20/'
base_sim_path = model_folder + 'OUTPUT_BASELINE/'
reform_sim_path = model_folder + 'OUTPUT_REFORM/'
growfactor_path = '../../Tax-Calculator-thru74/taxcalc/tmd_growfactors.csv'
output_path = model_folder + 'new_growfactors.csv'

# %%
gf.update(base_sim_path, reform_sim_path, growfactor_path, output_path)
