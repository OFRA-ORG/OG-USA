# %%
from run_og_usa_ext import *
from itertools import product

# %%
for frisch, zeta_D, g_y_annual, tG1 in product([0.3, 0.4], [0.2, 0.4], [0.02, 0.03], [15, 20]):
    main(frisch, zeta_D, g_y_annual, tG1)
    # print(frisch), print(zeta_D), print(g_y_annual), print(tG1)
# Out:
# Already did: TCJA##frisch##0.3##zeta_D##0.2##g_y_annual##0.02##tG1##15
# Already did: TCJA##frisch##0.3##zeta_D##0.2##g_y_annual##0.02##tG1##20
# Already did: TCJA##frisch##0.3##zeta_D##0.2##g_y_annual##0.03##tG1##15
# Already did: TCJA##frisch##0.3##zeta_D##0.2##g_y_annual##0.03##tG1##20
# Already did: TCJA##frisch##0.3##zeta_D##0.4##g_y_annual##0.02##tG1##15
# Already did: TCJA##frisch##0.3##zeta_D##0.4##g_y_annual##0.02##tG1##20
# Already did: TCJA##frisch##0.3##zeta_D##0.4##g_y_annual##0.03##tG1##15
# Already did: TCJA##frisch##0.3##zeta_D##0.4##g_y_annual##0.03##tG1##20
# Already did: TCJA##frisch##0.4##zeta_D##0.2##g_y_annual##0.02##tG1##15
# Already did: TCJA##frisch##0.4##zeta_D##0.2##g_y_annual##0.02##tG1##20
# Already did: TCJA##frisch##0.4##zeta_D##0.2##g_y_annual##0.03##tG1##15
# Already did: TCJA##frisch##0.4##zeta_D##0.2##g_y_annual##0.03##tG1##20
# Already did: TCJA##frisch##0.4##zeta_D##0.4##g_y_annual##0.02##tG1##15
# ...
