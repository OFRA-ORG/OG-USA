# %%
from run_og_usa_ext_tmd_immig import *
from itertools import product

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 20
immig_mil = 1
main_immig(frisch, zeta_D, g_y_annual, tG1, immig_mil)

# %%
frisch = 0.4
zeta_D = 0.4
g_y_annual = 0.02
tG1 = 20
immig_mil = 2
main_immig(frisch, zeta_D, g_y_annual, tG1, immig_mil)
